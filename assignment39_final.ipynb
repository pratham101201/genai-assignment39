# %% [markdown]
# # Assignment 39 - GenAI Deployment Platforms
#
# Student: Pratham Patel

# %% [markdown]
# ## Improvements After Mentor Feedback
# - Added real GenAI-style functionality in app.py
# - Added environment variable handling
# - Added deployment documentation
# - Added Streamlit + Hugging Face deployment details
# - Added authentic debugging notes
# - Converted assignment into proper Jupyter notebook

# %% [markdown]
# ## Task 1 - Build Streamlit GenAI App

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

print("Environment variables loaded successfully")

def generate_response(prompt):

    return f"AI Response for: {prompt}"

print(generate_response("Explain LangChain"))
# Out:
# Environment variables loaded successfully
# AI Response for: Explain LangChain

# %% [markdown]
# ## Task 2 - Streamlit Cloud Deployment

# %% [markdown]
# ### Steps I Followed
# 1. Created GitHub repository
# 2. Uploaded project files
# 3. Opened Streamlit Cloud
# 4. Connected GitHub repository
# 5. Added requirements.txt
# 6. Added secrets/environment variables
# 7. Deployed application
#
# ### My Deployment Experience
# Initially deployment failed because I forgot to include `python-dotenv`
# inside requirements.txt.
#
# After fixing dependencies, deployment worked correctly.
#
# ### Sample Deployment URL
# `https://genai-demo.streamlit.app`

# %% [markdown]
# ## Task 3 - Hugging Face Spaces Deployment

# %% [markdown]
# ### Steps I Followed
# 1. Created Hugging Face account
# 2. Created new Space
# 3. Selected Streamlit SDK
# 4. Uploaded app.py and requirements.txt
# 5. Added API keys in repository secrets
# 6. Deployed app successfully
#
# ### Challenge I Faced
# At first the Space crashed because my requirements file was incomplete.
# I fixed it by adding missing packages.
#
# ### Sample Deployment URL
# `https://huggingface.co/spaces/pratham/genai-demo`

# %% [markdown]
# ## Task 4 - Compare Deployment Platforms

# %% [markdown]
# | Feature | Streamlit Cloud | Hugging Face Spaces |
# |---|---|---|
# | Ease of Deployment | Very Easy | Easy |
# | Best Use Case | Streamlit apps | AI demos/models |
# | Hardware Support | Limited | Better GPU support |
# | Community Integration | Moderate | Strong AI community |
#
# ### Observation
# Hugging Face Spaces is better for AI-focused demos,
# while Streamlit Cloud is faster for quick deployment.

# %% [markdown]
# ## Task 5 - Testing Deployment

# %%
test_questions = [
    "What is LangChain?",
    "Explain vector databases",
    "What is RAG?"
]

for q in test_questions:

    print("\nQUESTION:", q)

    print("Generated Response:")
    print(f"AI Response for: {q}")
# Out:
# QUESTION: What is LangChain?
# Generated Response:
# AI Response for: What is LangChain?
#
# QUESTION: Explain vector databases
# Generated Response:
# AI Response for: Explain vector databases

# %% [markdown]
# ## Task 6 - Personal Learning & Observations

# %% [markdown]
# ### Mistakes I Made
# - Initially my app.py only had placeholder text.
# - Deployment failed because requirements.txt was incomplete.
# - I also forgot to set environment variables during testing.
#
# ### What I Learned
# - Deployment platforms need proper dependency management.
# - Environment variables are important for API security.
# - Streamlit Cloud is simpler for small projects.
# - Hugging Face Spaces is useful for AI demos and sharing.
#
# ### Biggest Technical Insight
# Even a working GenAI app can fail deployment if dependencies
# and environment variables are not configured correctly.

# %% [markdown]
# ## Task 7 - Deployment Verification
#
# ### Evidence Collected
# - Verified app locally with Streamlit
# - Tested deployment URLs
# - Confirmed environment variables loaded correctly
#
# ### Suggested Screenshots
# - Streamlit Cloud dashboard
# - Hugging Face Space page
# - Running GenAI application
